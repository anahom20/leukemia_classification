# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andrewmvd/leukemia-classification")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/andrewmvd/leukemia-classification?dataset_version_number=2...
# 100%|██████████| 867M/867M [00:14<00:00, 61.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2

# %%
import os

# List the contents of the downloaded directory
for root, dirs, files in os.walk(path):
    for name in files:
        print(os.path.join(root, name))
# Out:
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2200.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2184.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/921.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2152.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/637.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/966.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2410.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1798.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/146.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/97.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2541.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1132.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1598.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/8.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1411.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2030.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1011.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2257.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/313.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1747.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/652.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1209.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1631.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/431.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/954.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1743.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2573.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1719.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1445.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/436.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/413.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/405.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/344.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1860.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/746.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2318.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/73.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/42.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2297.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/49.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1369.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1168.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2167.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1875.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/956.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2046.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2484.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/251.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/805.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1961.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/501.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2398.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/371.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2566.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1868.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/612.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1861.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1423.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1490.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1076.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2248.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1969.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1248.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1734.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/106.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2087.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/137.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/479.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/517.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/647.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1730.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1649.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2285.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2522.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/596.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1555.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/757.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/743.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/175.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2428.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1741.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1945.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/595.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2168.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/415.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/421.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1548.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/232.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/77.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/864.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/820.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/513.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1908.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2131.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2436.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1883.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1893.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1479.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/925.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/271.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1265.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/297.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1006.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/199.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/270.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/779.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1459.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/666.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1582.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2128.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1487.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/918.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1926.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1153.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1843.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/913.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1165.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/121.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1007.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2291.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2076.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/345.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1188.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2345.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1654.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/848.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1049.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2494.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/17.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/278.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/463.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1792.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/938.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/814.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/126.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/653.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1057.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1022.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2057.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1776.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2574.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2132.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2539.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1295.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/835.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1623.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/998.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1551.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2001.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1456.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1536.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/104.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1133.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/514.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1951.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/245.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1820.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1050.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/424.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2394.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2212.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1241.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/391.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2581.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1220.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/592.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1047.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/736.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/500.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1519.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2119.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2471.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1495.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1206.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/973.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/333.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/30.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2409.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/404.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2258.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/782.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1192.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1765.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/9.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2171.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1099.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2392.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1489.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/312.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2513.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2204.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2173.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/939.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/94.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1318.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2081.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1579.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/80.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/561.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/792.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1061.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1505.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/477.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1898.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/163.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1970.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2542.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1254.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/999.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2395.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1395.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/958.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2210.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2251.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/164.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1152.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1106.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1503.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/268.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2495.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2185.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/238.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1252.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/447.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/800.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/242.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2015.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2104.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/439.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2256.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2412.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1737.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/407.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2469.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/337.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/498.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/88.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1557.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1450.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/896.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/547.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/264.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1481.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2545.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2552.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/240.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/619.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1597.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2572.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/675.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/673.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1035.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2537.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1468.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1170.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2396.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1698.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2243.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2422.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1120.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/765.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/351.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/853.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2403.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2033.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/299.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1477.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/292.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1577.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1586.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/338.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2517.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1715.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2281.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/296.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2365.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/265.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1791.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2064.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/281.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2188.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/724.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/443.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1581.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2085.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1567.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/807.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/791.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1721.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/790.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1525.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1784.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/302.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/272.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/183.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2377.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1197.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2045.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/172.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/994.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/91.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/150.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2464.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/752.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2328.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1155.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/716.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1249.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/967.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/446.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/910.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1270.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/84.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2323.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2039.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1938.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/381.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1805.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1583.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/747.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2092.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/246.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1853.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/43.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2508.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1062.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1517.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1554.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2006.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/613.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2308.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1680.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/930.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/893.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/599.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2478.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/38.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/340.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/2005.bmp
# ...
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1330.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/750.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1044.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/620.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/560.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/668.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1789.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/47.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/566.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/979.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1238.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/124.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/184.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1667.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/301.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/931.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/306.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/154.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/855.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1867.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/871.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/215.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/504.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/40.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1409.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1856.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/229.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/905.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1790.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1114.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1277.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1176.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/361.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/748.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/63.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1653.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/507.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1529.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/851.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1564.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/862.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/315.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1542.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/314.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1032.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/759.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/633.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1537.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1749.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/903.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1754.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/322.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/78.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1669.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1261.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1136.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/640.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/203.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1471.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/577.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/731.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1405.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/105.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1788.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1274.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/890.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1038.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1123.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1494.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/556.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/119.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1607.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/256.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/236.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1239.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/970.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1666.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1198.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/384.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1593.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/739.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/706.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1744.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1663.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1251.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1739.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/813.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1346.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1702.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1139.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1576.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/427.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1352.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1161.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1500.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1338.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/416.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1807.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/629.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1706.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1646.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1850.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/648.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/884.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1278.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1443.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/353.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/1671.bmp
# /root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/112.bmp

# %% [markdown]
# ###Preprocess the Data

# %%
# import os
# import cv2
# import numpy as np
# import random
# from tqdm import tqdm
# import matplotlib.pyplot as plt
# from sklearn.preprocessing import LabelEncoder
# from sklearn.utils import shuffle

# # Set seed for reproducibility
# random.seed(42)
# np.random.seed(42)

# # Set image size
# IMG_SIZE = (224, 224)

# # Get data paths
# train_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_0'
# val_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_1'
# test_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_2'

# def preprocess_data(base_path, img_size=(224, 224), augment_data=False):
#     X = []
#     y = []

#     for label_folder in os.listdir(base_path):
#         label_path = os.path.join(base_path, label_folder)
#         label = label_folder  # 'all' or 'hem'

#         for img_name in tqdm(os.listdir(label_path), desc=f'Processing {label_folder}'):
#             img_path = os.path.join(label_path, img_name)
#             img = cv2.imread(img_path)

#             if img is None:
#                 continue

#             img = cv2.resize(img, img_size)
#             img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#             img = img.astype('float32') / 255.0  # normalise

#             X.append(img)
#             y.append(label)

#             # Data Augmentation (only for training data)
#             if augment_data:
#                 # Horizontal flip
#                 flipped = cv2.flip(img, 1)
#                 X.append(flipped)
#                 y.append(label)

#                 # Random rotation
#                 angle = random.choice([90, 180, 270])
#                 M = cv2.getRotationMatrix2D((img_size[0] // 2, img_size[1] // 2), angle, 1)
#                 rotated = cv2.warpAffine(img, M, img_size)
#                 X.append(rotated)
#                 y.append(label)

#                 # Brightness jitter
#                 brightness = random.uniform(0.7, 1.3)
#                 bright = np.clip(img * brightness, 0, 1).astype(np.float32)
#                 X.append(bright)
#                 y.append(label)


#     X = np.array(X)
#     y = np.array(y)

#     # Encode labels
#     le = LabelEncoder()
#     y = le.fit_transform(y)

#     # Shuffle
#     X, y = shuffle(X, y, random_state=42)

#     return X, y



# # Preprocess all sets
# X_train, y_train = preprocess_data(train_path, augment_data=True)
# X_val, y_val     = preprocess_data(val_path, augment_data=False)
# X_test, y_test   = preprocess_data(test_path, augment_data=False)

# print("Shapes:")
# print("Train:", X_train.shape, y_train.shape)
# print("Val:", X_val.shape, y_val.shape)
# print("Test:", X_test.shape, y_test.shape)

# %%
import os
import cv2
import numpy as np
import random
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Constants
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
train_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_0'
val_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_1'
test_path = '/root/.cache/kagglehub/datasets/andrewmvd/leukemia-classification/versions/2/C-NMC_Leukemia/training_data/fold_2'


class LeukemiaDataGenerator:
    def __init__(self, base_path, batch_size=32, img_size=(224, 224), augment=False, shuffle=True):
        self.base_path = base_path
        self.batch_size = batch_size
        self.img_size = img_size
        self.augment = augment
        self.shuffle = shuffle
        self.label_encoder = LabelEncoder()
        self.samples = self._load_file_paths()
        self.on_epoch_end()

    def _load_file_paths(self):
        samples = []
        labels = []
        for label_folder in os.listdir(self.base_path):
            label_path = os.path.join(self.base_path, label_folder)
            if not os.path.isdir(label_path):
                continue
            for img_name in os.listdir(label_path):
                samples.append(os.path.join(label_path, img_name))
                labels.append(label_folder)
        self.label_encoder.fit(labels)
        return list(zip(samples, labels))

    def __len__(self):
        return int(np.ceil(len(self.samples) / self.batch_size))

    def __getitem__(self, idx):
        batch_samples = self.samples[idx * self.batch_size:(idx + 1) * self.batch_size]
        X, y = self._load_and_preprocess_batch(batch_samples)
        return np.array(X), np.array(y)

    def _load_and_preprocess_batch(self, batch_samples):
        X = []
        y = []
        for img_path, label in batch_samples:
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.resize(img, self.img_size)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = img.astype('float32') / 255.0

            X.append(img)
            y.append(label)

            if self.augment:
                # Horizontal flip
                X.append(cv2.flip(img, 1))
                y.append(label)

                # Random rotation
                angle = random.choice([90, 180, 270])
                M = cv2.getRotationMatrix2D((self.img_size[0] // 2, self.img_size[1] // 2), angle, 1)
                rotated = cv2.warpAffine(img, M, self.img_size)
                X.append(rotated)
                y.append(label)

                # Brightness jitter
                brightness = random.uniform(0.7, 1.3)
                bright = np.clip(img * brightness, 0, 1).astype(np.float32)
                X.append(bright)
                y.append(label)

        y = self.label_encoder.transform(y)
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.samples)

# %%
train_gen = LeukemiaDataGenerator(train_path, batch_size=32, augment=True)
val_gen   = LeukemiaDataGenerator(val_path, batch_size=32, augment=False)
test_gen  = LeukemiaDataGenerator(test_path, batch_size=32, augment=False)

# Example: get one batch
X_batch, y_batch = train_gen[0]
print("Batch shape:", X_batch.shape, y_batch.shape)
# Out:
# Batch shape: (128, 224, 224, 3) (128,)

# %% [markdown]
# ###Data Visualisations

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def extract_all_labels(data_generator):
    all_labels = []
    for i in range(len(data_generator)):
        _, y_batch = data_generator[i]
        all_labels.extend(y_batch)
    return np.array(all_labels)

# %%
def plot_class_distribution(y, title):
    plt.figure(figsize=(6, 4))
    sns.countplot(x=y)
    plt.title(title)
    plt.xlabel("Class (0: ALL, 1: HEM)")
    plt.ylabel("Count")
    plt.show()

# Get all labels from generators
y_train_all = extract_all_labels(train_gen)
y_val_all   = extract_all_labels(val_gen)
y_test_all  = extract_all_labels(test_gen)

# Plot
plot_class_distribution(y_train_all, "Training Class Distribution")
plot_class_distribution(y_val_all, "Validation Class Distribution")
plot_class_distribution(y_test_all, "Test Class Distribution")

# %%
# def plot_pixel_histogram(X, title="Normalized Pixel Intensity Distribution"):
#     pixels = X.flatten()
#     plt.figure(figsize=(8, 4))
#     plt.hist(pixels, bins=50, color='skyblue')
#     plt.title(title)
#     plt.xlabel("Pixel Value")
#     plt.ylabel("Frequency")
#     plt.grid(True)
#     plt.show()

# plot_pixel_histogram(X_train, "Pixel Intensity Distribution (Train Set)")

# %%
# def show_sample_images(X, y, label_map, title="Sample Images", num_samples=5):
#     plt.figure(figsize=(15, 4))
#     for label in np.unique(y):
#         idxs = np.where(y == label)[0]
#         chosen = np.random.choice(idxs, size=num_samples, replace=False)
#         for i, idx in enumerate(chosen):
#             plt.subplot(len(np.unique(y)), num_samples, label * num_samples + i + 1)
#             plt.imshow(X[idx])
#             plt.axis('off')
#             if i == 0:
#                 plt.ylabel(label_map[label], fontsize=12)
#     plt.suptitle(title)
#     plt.tight_layout()
#     plt.show()

# label_map = {0: "ALL", 1: "HEM"}  # Adjust if label encoding changes
# show_sample_images(X_train, y_train, label_map, "Sample Images from Training Set")


def get_sample_images(generator, num_per_class=5):
    images_by_class = {}
    for i in range(len(generator)):
        X_batch, y_batch = generator[i]
        for img, label in zip(X_batch, y_batch):
            if label not in images_by_class:
                images_by_class[label] = []
            if len(images_by_class[label]) < num_per_class:
                images_by_class[label].append(img)
        # Stop early if we have enough for all classes
        if all(len(imgs) >= num_per_class for imgs in images_by_class.values()):
            break
    return images_by_class

def show_sample_images_from_generator(generator, label_map, title="Sample Images", num_samples=5):
    samples = get_sample_images(generator, num_samples)
    num_classes = len(samples)

    plt.figure(figsize=(15, 3 * num_classes))
    for row_idx, (label, images) in enumerate(samples.items()):
        for col_idx, img in enumerate(images):
            plt.subplot(num_classes, num_samples, row_idx * num_samples + col_idx + 1)
            plt.imshow(img)
            plt.axis('off')
            if col_idx == 0:
                plt.ylabel(label_map[label], fontsize=12)
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

label_map = {0: "ALL", 1: "HEM"}
show_sample_images_from_generator(train_gen, label_map, "Sample Images from Training Set")

# %%
# # Show original, flipped, and rotated versions of one image
# def show_augmentation_example(img):
#     img = cv2.resize(img, IMG_SIZE)
#     flipped = cv2.flip(img, 1)
#     angle = 90
#     M = cv2.getRotationMatrix2D((IMG_SIZE[0] // 2, IMG_SIZE[1] // 2), angle, 1)
#     rotated = cv2.warpAffine(img, M, IMG_SIZE)

#     images = [img, flipped, rotated]
#     titles = ['Original', 'Flipped', 'Rotated 90°']

#     plt.figure(figsize=(12, 4))
#     for i in range(3):
#         plt.subplot(1, 3, i + 1)
#         plt.imshow(images[i])
#         plt.title(titles[i])
#         plt.axis('off')
#     plt.suptitle("Augmentation Example")
#     plt.tight_layout()
#     plt.show()

# # Show using a random training image
# show_augmentation_example(X_train[0])

# %%
def plot_pie_chart(y, title):
    labels = ['ALL', 'HEM']
    counts = [np.sum(y == 0), np.sum(y == 1)]
    plt.figure(figsize=(5, 5))
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140, explode=(0.05, 0.05))
    plt.title(title)
    plt.show()

plot_pie_chart(y_train_all, "Train Class Proportion")
plot_pie_chart(y_val_all, "Validation Class Proportion")
plot_pie_chart(y_test_all, "Test Class Proportion")

# %%
# import pandas as pd

# def plot_brightness_distribution(X, y, title):
#     brightness = [np.mean(img) for img in X]
#     sns.histplot(data=pd.DataFrame({'Brightness': brightness, 'Label': y}),
#                  x="Brightness", hue="Label", bins=50, palette='husl')
#     plt.title(title)
#     plt.xlabel("Average Brightness")
#     plt.ylabel("Frequency")
#     plt.show()

# plot_brightness_distribution(X_train, y_train, "Brightness Distribution (Train Set)")

# %%
def apply_augmentations_from_generator(generator, img, img_size=(224, 224)):
    augmented_images = [img]  # original

    # Horizontal flip
    flipped = cv2.flip(img, 1)
    augmented_images.append(flipped)

    # Random rotations
    for angle in [90, 180, 270]:
        M = cv2.getRotationMatrix2D((img_size[0] // 2, img_size[1] // 2), angle, 1)
        rotated = cv2.warpAffine(img, M, img_size)
        augmented_images.append(rotated)

    # Brightness jitter (show both dimmer and brighter)
    for brightness in [0.7, 1.3]:
        bright = np.clip(img * brightness, 0, 1).astype(np.float32)
        augmented_images.append(bright)

    return augmented_images

import matplotlib.pyplot as plt

def show_augmented_versions_from_generator(generator, img_size=(224, 224)):
    X_batch, y_batch = generator[0]
    img = X_batch[0]  # First image
    label = y_batch[0]

    aug_imgs = apply_augmentations_from_generator(generator, img, img_size)

    plt.figure(figsize=(18, 3))
    for i, aug_img in enumerate(aug_imgs):
        plt.subplot(1, len(aug_imgs), i + 1)
        plt.imshow(aug_img)
        plt.axis('off')
        plt.title("Original" if i == 0 else f"Aug {i}")
    plt.suptitle(f"Augmented Versions (Label: {label})", fontsize=14)
    plt.tight_layout()
    plt.show()


# Make sure to create a non-augmented generator to fetch the original clean image
clean_gen = LeukemiaDataGenerator(train_path, augment=False)
show_augmented_versions_from_generator(clean_gen)
